# %%
import pandas as pd

# %%
data = pd.read_csv("D:\employee salary prediction\Employees (1).csv")

# %%
data.head()
# Out:
#    No First Name Last Name  Gender Start Date  Years          Department  \
# 0   1     Ghadir     Hmshw    Male   4/4/2018      7     Quality Control
# 1   2       Omar    Hishan    Male  5/21/2020      5     Quality Control
# 2   3      Ailya    Sharaf  Female  9/28/2017      7  Major Mfg Projects
# 3   4       Lwiy     Qbany    Male  8/14/2018      6       Manufacturing
# 4   5      Ahmad     Bikri    Male  3/11/2020      5       Manufacturing
#
#                 Country Center  Monthly Salary  Annual Salary  Job Rate  \
# 0                 Egypt   West            1560          18720       3.0
# 1          Saudi Arabia   West            3247          38964       1.0
# 2          Saudi Arabia   West            2506          30072       2.0
# 3  United Arab Emirates   Main            1828          21936       3.0
# 4                 Egypt   Main             970          11640       5.0
#
#    Sick Leaves  Unpaid Leaves  Overtime Hours
# 0            1              0             183
# 1            0              5             198
# 2            0              3             192
# 3            0              0               7
# 4            0              5             121

# %%
data.head(6)
# Out:
#    No First Name Last Name  Gender Start Date  Years           Department  \
# 0   1     Ghadir     Hmshw    Male   4/4/2018      7      Quality Control
# 1   2       Omar    Hishan    Male  5/21/2020      5      Quality Control
# 2   3      Ailya    Sharaf  Female  9/28/2017      7   Major Mfg Projects
# 3   4       Lwiy     Qbany    Male  8/14/2018      6        Manufacturing
# 4   5      Ahmad     Bikri    Male  3/11/2020      5        Manufacturing
# 5   6    Muhamad    Zueitr    Male   2/2/2016      9  Product Development
#
#                 Country Center  Monthly Salary  Annual Salary  Job Rate  \
# 0                 Egypt   West            1560          18720       3.0
# 1          Saudi Arabia   West            3247          38964       1.0
# 2          Saudi Arabia   West            2506          30072       2.0
# 3  United Arab Emirates   Main            1828          21936       3.0
# 4                 Egypt   Main             970          11640       5.0
# 5          Saudi Arabia  North            2332          27984       3.0
#
#    Sick Leaves  Unpaid Leaves  Overtime Hours
# 0            1              0             183
# 1            0              5             198
# 2            0              3             192
# 3            0              0               7
# 4            0              5             121
# 5            3              0               8

# %%
data.tail(7)
# Out:
#       No   First Name Last Name Gender Start Date  Years  \
# 682  683        Husam    Alsaed   Male  5/12/2016      9
# 683  684          Asd   Bwfaeur   Male  6/27/2017      8
# 684  685         Sari     Hanna   Male  5/26/2020      5
# 685  686      Eubayda      Kayd   Male   6/3/2020      5
# 686  687       Khalil    Alkalu   Male  7/11/2017      8
# 687  688      Muhamad    Shrbjy   Male  5/30/2018      7
# 688  689  Abd Albasit   AlAhmar   Male   8/5/2020      4
#
#                  Department               Country Center  Monthly Salary  \
# 682      Account Management  United Arab Emirates   Main            2147
# 683                      IT                 Egypt   Main            2929
# 684               Marketing               Lebanon  South            1452
# 685  Facilities/Engineering                 Egypt  North            3237
# 686  Facilities/Engineering                 Egypt  North            2819
# 687                Creative                 Egypt  North            2069
# 688                      IT  United Arab Emirates  North            2606
#
#      Annual Salary  Job Rate  Sick Leaves  Unpaid Leaves  Overtime Hours
# 682          25764       3.0            0              4               2
# 683          35148       4.5            0              0               2
# 684          17424       2.0            0              3               1
# 685          38844       3.0            1              0               4
# 686          33828       5.0            0              0               0
# 687          24828       3.0            0              0              10
# 688          31272       5.0            0              0               0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              689 non-null    int64
#  1   First Name      689 non-null    object
#  2   Last Name       689 non-null    object
#  3   Gender          689 non-null    object
#  4   Start Date      689 non-null    object
#  5   Years           689 non-null    int64
#  6   Department      689 non-null    object
#  7   Country         689 non-null    object
#  8   Center          689 non-null    object
#  9   Monthly Salary  689 non-null    int64
#  10  Annual Salary   689 non-null    int64
#  11  Job Rate        689 non-null    float64
#  12  Sick Leaves     689 non-null    int64
#  13  Unpaid Leaves   689 non-null    int64
#  14  Overtime Hours  689 non-null    int64
# dtypes: float64(1), int64(7), object(7)
# memory usage: 80.9+ KB

# %%
data.shape
# Out:
# (689, 15)

# %%
data.isna().sum()
# Out:
# No                0
# First Name        0
# Last Name         0
# Gender            0
# Start Date        0
# Years             0
# Department        0
# Country           0
# Center            0
# Monthly Salary    0
# Annual Salary     0
# Job Rate          0
# Sick Leaves       0
# Unpaid Leaves     0
# Overtime Hours    0
# dtype: int64

# %%
#data.dropna(inplace=True) For dropping NA values in the dataset

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt

# %%
data["Gender"].value_counts()
# Out:
# Gender
# Male      449
# Female    240
# Name: count, dtype: int64

# %%
data["Gender"].value_counts().sort_values(ascending = False).plot(kind = "pie")
plt.title("Pie Chart of Gender column")
plt.ylabel("")
plt.show()

# %%
data.head(2)
# Out:
#    No First Name Last Name Gender Start Date  Years       Department  \
# 0   1     Ghadir     Hmshw   Male   4/4/2018      7  Quality Control
# 1   2       Omar    Hishan   Male  5/21/2020      5  Quality Control
#
#         Country Center  Monthly Salary  Annual Salary  Job Rate  Sick Leaves  \
# 0         Egypt   West            1560          18720       3.0            1
# 1  Saudi Arabia   West            3247          38964       1.0            0
#
#    Unpaid Leaves  Overtime Hours
# 0              0             183
# 1              5             198

# %%
plt.hist(data["Job Rate"])
# Out:
# (array([ 70.,   0.,  72.,   0.,   0., 208.,   0.,   0., 124., 215.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["Job Rate"])
plt.title("Histrogram of Job Rates")
plt.xlabel("Rate")
plt.ylabel("Count")
plt.show()

# %%
data["Job Rate"].describe()
# Out:
# count    689.000000
# mean       3.586357
# std        1.350125
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        5.000000
# max        5.000000
# Name: Job Rate, dtype: float64

# %%
data.head()
# Out:
#    No First Name Last Name  Gender Start Date  Years          Department  \
# 0   1     Ghadir     Hmshw    Male   4/4/2018      7     Quality Control
# 1   2       Omar    Hishan    Male  5/21/2020      5     Quality Control
# 2   3      Ailya    Sharaf  Female  9/28/2017      7  Major Mfg Projects
# 3   4       Lwiy     Qbany    Male  8/14/2018      6       Manufacturing
# 4   5      Ahmad     Bikri    Male  3/11/2020      5       Manufacturing
#
#                 Country Center  Monthly Salary  Annual Salary  Job Rate  \
# 0                 Egypt   West            1560          18720       3.0
# 1          Saudi Arabia   West            3247          38964       1.0
# 2          Saudi Arabia   West            2506          30072       2.0
# 3  United Arab Emirates   Main            1828          21936       3.0
# 4                 Egypt   Main             970          11640       5.0
#
#    Sick Leaves  Unpaid Leaves  Overtime Hours
# 0            1              0             183
# 1            0              5             198
# 2            0              3             192
# 3            0              0               7
# 4            0              5             121

# %%
data.groupby("Department")["Annual Salary"].mean()
# Out:
# Department
# Account Management             23246.000000
# Creative                       24135.789474
# Environmental Compliance       30097.846154
# Environmental Health/Safety    24005.333333
# Facilities/Engineering         27423.310345
# Green Building                 24994.500000
# Human Resources                30670.285714
# IT                             25374.300000
# Major Mfg Projects             26908.500000
# Manufacturing                  24055.628571
# Manufacturing Admin            23052.000000
# Marketing                      24733.500000
# Product Development            23576.470588
# Professional Training Group    24485.142857
# Quality Assurance              25007.104478
# Quality Control                24647.460674
# Research Center                22644.000000
# Research/Development           25183.200000
# Sales                          23477.400000
# Training                       28341.000000
# Name: Annual Salary, dtype: float64

# %%
data.groupby("Department")["Annual Salary"].mean().sort_values(ascending= False).plot(kind = "bar")
# Out:
# <Axes: xlabel='Department'>

# %%
data.groupby("Department")["Annual Salary"].mean().sort_values(ascending= False)
# Out:
# Department
# Human Resources                30670.285714
# Environmental Compliance       30097.846154
# Training                       28341.000000
# Facilities/Engineering         27423.310345
# Major Mfg Projects             26908.500000
# IT                             25374.300000
# Research/Development           25183.200000
# Quality Assurance              25007.104478
# Green Building                 24994.500000
# Marketing                      24733.500000
# Quality Control                24647.460674
# Professional Training Group    24485.142857
# Creative                       24135.789474
# Manufacturing                  24055.628571
# Environmental Health/Safety    24005.333333
# Product Development            23576.470588
# Sales                          23477.400000
# Account Management             23246.000000
# Manufacturing Admin            23052.000000
# Research Center                22644.000000
# Name: Annual Salary, dtype: float64

# %%
data.groupby("Department")["Annual Salary"].mean().sort_values(ascending= False).head(7)
# Out:
# Department
# Human Resources             30670.285714
# Environmental Compliance    30097.846154
# Training                    28341.000000
# Facilities/Engineering      27423.310345
# Major Mfg Projects          26908.500000
# IT                          25374.300000
# Research/Development        25183.200000
# Name: Annual Salary, dtype: float64

# %%
data.groupby("Department")["Annual Salary"].mean().sort_values(ascending= False).head(7).plot(kind = "bar")
# Out:
# <Axes: xlabel='Department'>

# %%
data.groupby("Department")["Annual Salary"].mean().sort_values(ascending= False).head(7).plot(kind = "bar")
plt.title("Average Salary Graph by Department")
plt.xlabel("Department")
plt.ylabel("Average Salary")
plt.show()

# %%
data
# Out:
#       No   First Name Last Name  Gender Start Date  Years  \
# 0      1       Ghadir     Hmshw    Male   4/4/2018      7
# 1      2         Omar    Hishan    Male  5/21/2020      5
# 2      3        Ailya    Sharaf  Female  9/28/2017      7
# 3      4         Lwiy     Qbany    Male  8/14/2018      6
# 4      5        Ahmad     Bikri    Male  3/11/2020      5
# ..   ...          ...       ...     ...        ...    ...
# 684  685         Sari     Hanna    Male  5/26/2020      5
# 685  686      Eubayda      Kayd    Male   6/3/2020      5
# 686  687       Khalil    Alkalu    Male  7/11/2017      8
# 687  688      Muhamad    Shrbjy    Male  5/30/2018      7
# 688  689  Abd Albasit   AlAhmar    Male   8/5/2020      4
#
#                  Department               Country Center  Monthly Salary  \
# 0           Quality Control                 Egypt   West            1560
# 1           Quality Control          Saudi Arabia   West            3247
# 2        Major Mfg Projects          Saudi Arabia   West            2506
# 3             Manufacturing  United Arab Emirates   Main            1828
# 4             Manufacturing                 Egypt   Main             970
# ..                      ...                   ...    ...             ...
# 684               Marketing               Lebanon  South            1452
# 685  Facilities/Engineering                 Egypt  North            3237
# 686  Facilities/Engineering                 Egypt  North            2819
# 687                Creative                 Egypt  North            2069
# 688                      IT  United Arab Emirates  North            2606
#
#      Annual Salary  Job Rate  Sick Leaves  Unpaid Leaves  Overtime Hours
# 0            18720       3.0            1              0             183
# 1            38964       1.0            0              5             198
# 2            30072       2.0            0              3             192
# 3            21936       3.0            0              0               7
# 4            11640       5.0            0              5             121
# ..             ...       ...          ...            ...             ...
# 684          17424       2.0            0              3               1
# 685          38844       3.0            1              0               4
# 686          33828       5.0            0              0               0
# 687          24828       3.0            0              0              10
# 688          31272       5.0            0              0               0
#
# [689 rows x 15 columns]

# %%
data.groupby("Center")["Monthly Salary"].mean().sort_values(ascending = False)
# Out:
# Center
# East     2274.021277
# West     2068.672269
# North    2064.811594
# Main     2054.776892
# South    1981.153846
# Name: Monthly Salary, dtype: float64

# %%
data["Country"].unique()
# Out:
# array(['Egypt', 'Saudi Arabia', 'United Arab Emirates', 'Syria',
#        'Lebanon'], dtype=object)

# %%
data.groupby("Country")["Job Rate"].mean().sort_values(ascending=False).plot(kind="bar")
plt.title("Job Rates by Countries")
plt.xlabel("Country")
plt.ylabel("Job Rates Average")
plt.show()

# %%
plt.hist(data ["Overtime Hours"])
plt.title("Histogram of Overtime Hours")
plt.xlabel("Overtime Hours")
plt.ylabel("Frequency")
plt.show()

# %%
data["Overtime Hours"].describe()
# Out:
# count    689.000000
# mean      13.702467
# std       25.692049
# min        0.000000
# 25%        3.000000
# 50%        7.000000
# 75%       10.000000
# max      198.000000
# Name: Overtime Hours, dtype: float64

# %%
data["Annual Salary"].describe()
# Out:
# count      689.000000
# mean     24818.420900
# std       9159.470878
# min       8436.000000
# 25%      17232.000000
# 50%      24924.000000
# 75%      32184.000000
# max      41400.000000
# Name: Annual Salary, dtype: float64

# %%
data.columns
# Out:
# Index(['No', 'First Name', 'Last Name', 'Gender', 'Start Date', 'Years',
#        'Department', 'Country', 'Center', 'Monthly Salary', 'Annual Salary',
#        'Job Rate', 'Sick Leaves', 'Unpaid Leaves', 'Overtime Hours'],
#       dtype='object')

# %%
x = data[["Years","Job Rate"]]
y = data["Annual Salary"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.2)

# %%
len(y_train)
# Out:
# 551

# %%
len(x_test)
# Out:
# 138

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predslr = lr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(predslr,y_test)
# Out:
# 7776.519385647256

# %%
x
# Out:
#      Years  Job Rate
# 0        7       3.0
# 1        5       1.0
# 2        7       2.0
# 3        6       3.0
# 4        5       5.0
# ..     ...       ...
# 684      5       2.0
# 685      5       3.0
# 686      8       5.0
# 687      7       3.0
# 688      4       5.0
#
# [689 rows x 2 columns]

# %%
import joblib
joblib.dump(lr,"Linearmodel.pkl")
# Out:
# ['Linearmodel.pkl']
